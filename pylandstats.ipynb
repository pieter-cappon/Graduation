# %%
import pylandstats as pls

# %%
raster = pls.Landscape(landscape="C:/Users/piete/Documents/HU/DDD/D/Prototype/Data/Remote Sensing/S2A_MSIL2A_20200507T104031_N0214_R008_T31UFT_20200507T133648.SAFE/GRANULE/L2A_T31UFT_A025459_20200507T104558/IMG_DATA/Utrecht_Definitief/Classifications/clip_utrecht.tif")
raster.plot_landscape(legend=True)

# %%
total_df = raster.compute_class_metrics_df(
    metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn'])
total_df = total_df.iloc[[1]]
total_df['Area']='Utrecht'
total_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\envs\eolearn\lib\site-packages\pylandstats\landscape.py in _patch_euclidean_nearest_neighbor_ser(self)
#     442         try:
# --> 443             return self._cached_patch_euclidean_nearest_neighbor_ser
#     444         except AttributeError:
#
# AttributeError: 'Landscape' object has no attribute '_cached_patch_euclidean_nearest_neighbor_ser'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-89f9eff9020e> in <module>
#       1 total_df = raster.compute_class_metrics_df(
# ----> 2     metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn', 'euclidean_nearest_neighbor_mn'])
#       3 total_df = total_df.iloc[[1]]
#       4 total_df['Area']='Utrecht'
# ...

# %%
binnenstad = pls.Landscape(landscape="C:/Users/piete/Documents/HU/DDD/D/Prototype/Data/Remote Sensing/S2A_MSIL2A_20200507T104031_N0214_R008_T31UFT_20200507T133648.SAFE/GRANULE/L2A_T31UFT_A025459_20200507T104558/IMG_DATA/Utrecht_Definitief/Classifications/binnenstad_classification.tif")

binnenstad_df = binnenstad.compute_class_metrics_df(
    metrics=['total_area', 'proportion_of_landscape'])
binnenstad_df = binnenstad_df.iloc[[1]]
binnenstad_df['Area']='Binnenstad'
binnenstad_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-23449b98fbc9> in <module>
#       2
#       3 binnenstad_df = binnenstad.compute_class_metrics_df(
# ----> 4     metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn', 'euclidean_nearest_neighbor'])
#       5 binnenstad_df = binnenstad_df.iloc[[1]]
#       6 binnenstad_df['Area']='Binnenstad'
#
# ~\anaconda3\envs\eolearn\lib\site-packages\pylandstats\landscape.py in compute_class_metrics_df(self, metrics, classes, metrics_kws)
#    2567                     raise ValueError(
#    2568                         "{metric} cannot be computed at the class level".
# -> 2569                         format(metric=metric))
#    2570
#    2571         if classes is None:
#
# ValueError: euclidean_nearest_neighbor cannot be computed at the class level

# %%
leidsche_rijn = pls.Landscape(landscape="C:/Users/piete/Documents/HU/DDD/D/Prototype/Data/Remote Sensing/S2A_MSIL2A_20200507T104031_N0214_R008_T31UFT_20200507T133648.SAFE/GRANULE/L2A_T31UFT_A025459_20200507T104558/IMG_DATA/Utrecht_Definitief/Classifications/leidsche_rijn_classification.tif")

leidsche_rijn_df = leidsche_rijn.compute_class_metrics_df(
    metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn', 'euclidean_nearest_neighbor_mn'])
leidsche_rijn_df = leidsche_rijn_df.iloc[[1]]
leidsche_rijn_df['Area']='Leidsche Rijn'
leidsche_rijn_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-1755fc1aa91f> in <module>
#       2
#       3 leidsche_rijn_df = leidsche_rijn.compute_class_metrics_df(
# ----> 4     metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn', 'euclidean_nearest_neighbor'])
#       5 leidsche_rijn_df = leidsche_rijn_df.iloc[[1]]
#       6 leidsche_rijn_df['Area']='Leidsche Rijn'
#
# ~\anaconda3\envs\eolearn\lib\site-packages\pylandstats\landscape.py in compute_class_metrics_df(self, metrics, classes, metrics_kws)
#    2567                     raise ValueError(
#    2568                         "{metric} cannot be computed at the class level".
# -> 2569                         format(metric=metric))
#    2570
#    2571         if classes is None:
#
# ValueError: euclidean_nearest_neighbor cannot be computed at the class level

# %%
noordoost = pls.Landscape(landscape="C:/Users/piete/Documents/HU/DDD/D/Prototype/Data/Remote Sensing/S2A_MSIL2A_20200507T104031_N0214_R008_T31UFT_20200507T133648.SAFE/GRANULE/L2A_T31UFT_A025459_20200507T104558/IMG_DATA/Utrecht_Definitief/Classifications/noordoost_classification.tif")

noordoost_df = noordoost.compute_class_metrics_df(
    metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn', 'euclidean_nearest_neighbor_mn'])
noordoost_df = noordoost_df.iloc[[0]]
noordoost_df['Area']='Noordoost'
noordoost_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-7bc047f8d79a> in <module>
#       2
#       3 noordoost_df = noordoost.compute_class_metrics_df(
# ----> 4     metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn', 'euclidean_nearest_neighbor'])
#       5 noordoost_df = noordoost_df.iloc[[0]]
#       6 noordoost_df['Area']='Noordoost'
#
# ~\anaconda3\envs\eolearn\lib\site-packages\pylandstats\landscape.py in compute_class_metrics_df(self, metrics, classes, metrics_kws)
#    2567                     raise ValueError(
#    2568                         "{metric} cannot be computed at the class level".
# -> 2569                         format(metric=metric))
#    2570
#    2571         if classes is None:
#
# ValueError: euclidean_nearest_neighbor cannot be computed at the class level

# %%
noordwest = pls.Landscape(landscape="C:/Users/piete/Documents/HU/DDD/D/Prototype/Data/Remote Sensing/S2A_MSIL2A_20200507T104031_N0214_R008_T31UFT_20200507T133648.SAFE/GRANULE/L2A_T31UFT_A025459_20200507T104558/IMG_DATA/Utrecht_Definitief/Classifications/noordwest_classification.tif")

noordwest_df = noordwest.compute_class_metrics_df(
    metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn', 'euclidean_nearest_neighbor_mn'])
noordwest_df = noordwest_df.iloc[[0]]
noordwest_df['Area']='Noordwest'
noordwest_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-52fb98f71cd3> in <module>
#       2
#       3 noordwest_df = noordwest.compute_class_metrics_df(
# ----> 4     metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn', 'euclidean_nearest_neighbor'])
#       5 noordwest_df = noordwest_df.iloc[[0]]
#       6 noordwest_df['Area']='Noordwest'
#
# ~\anaconda3\envs\eolearn\lib\site-packages\pylandstats\landscape.py in compute_class_metrics_df(self, metrics, classes, metrics_kws)
#    2567                     raise ValueError(
#    2568                         "{metric} cannot be computed at the class level".
# -> 2569                         format(metric=metric))
#    2570
#    2571         if classes is None:
#
# ValueError: euclidean_nearest_neighbor cannot be computed at the class level

# %%
oost = pls.Landscape(landscape="C:/Users/piete/Documents/HU/DDD/D/Prototype/Data/Remote Sensing/S2A_MSIL2A_20200507T104031_N0214_R008_T31UFT_20200507T133648.SAFE/GRANULE/L2A_T31UFT_A025459_20200507T104558/IMG_DATA/Utrecht_Definitief/Classifications/oost_classification.tif")

oost_df = oost.compute_class_metrics_df(
    metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn', 'euclidean_nearest_neighbor_mn'])
oost_df = oost_df.iloc[[0]]
oost_df['Area']='Oost'
oost_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-f489a170ae23> in <module>
#       2
#       3 oost_df = oost.compute_class_metrics_df(
# ----> 4     metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn', 'euclidean_nearest_neighbor'])
#       5 oost_df = oost_df.iloc[[0]]
#       6 oost_df['Area']='Oost'
#
# ~\anaconda3\envs\eolearn\lib\site-packages\pylandstats\landscape.py in compute_class_metrics_df(self, metrics, classes, metrics_kws)
#    2567                     raise ValueError(
#    2568                         "{metric} cannot be computed at the class level".
# -> 2569                         format(metric=metric))
#    2570
#    2571         if classes is None:
#
# ValueError: euclidean_nearest_neighbor cannot be computed at the class level

# %%
overvecht = pls.Landscape(landscape="C:/Users/piete/Documents/HU/DDD/D/Prototype/Data/Remote Sensing/S2A_MSIL2A_20200507T104031_N0214_R008_T31UFT_20200507T133648.SAFE/GRANULE/L2A_T31UFT_A025459_20200507T104558/IMG_DATA/Utrecht_Definitief/Classifications/overvecht_classification.tif")

overvecht_df = overvecht.compute_class_metrics_df(
    metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn', 'euclidean_nearest_neighbor_mn'])
overvecht_df = overvecht_df.iloc[[0]]
overvecht_df['Area']='Overvecht'
overvecht_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-b0fa6d9b25dc> in <module>
#       2
#       3 overvecht_df = overvecht.compute_class_metrics_df(
# ----> 4     metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn', 'euclidean_nearest_neighbor'])
#       5 overvecht_df = overvecht_df.iloc[[0]]
#       6 overvecht_df['Area']='Overvecht'
#
# ~\anaconda3\envs\eolearn\lib\site-packages\pylandstats\landscape.py in compute_class_metrics_df(self, metrics, classes, metrics_kws)
#    2567                     raise ValueError(
#    2568                         "{metric} cannot be computed at the class level".
# -> 2569                         format(metric=metric))
#    2570
#    2571         if classes is None:
#
# ValueError: euclidean_nearest_neighbor cannot be computed at the class level

# %%
vleuten_de_meern = pls.Landscape(landscape="C:/Users/piete/Documents/HU/DDD/D/Prototype/Data/Remote Sensing/S2A_MSIL2A_20200507T104031_N0214_R008_T31UFT_20200507T133648.SAFE/GRANULE/L2A_T31UFT_A025459_20200507T104558/IMG_DATA/Utrecht_Definitief/Classifications/vleuten_de_meern_classification.tif")

vleuten_de_meern_df = vleuten_de_meern.compute_class_metrics_df(
    metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn', 'euclidean_nearest_neighbor_mn'])
vleuten_de_meern_df = vleuten_de_meern_df.iloc[[0]]
vleuten_de_meern_df['Area']='Vleuten - De Meern'
vleuten_de_meern_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-29791bec671f> in <module>
#       2
#       3 vleuten_de_meern_df = vleuten_de_meern.compute_class_metrics_df(
# ----> 4     metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn', 'euclidean_nearest_neighbor'])
#       5 vleuten_de_meern_df = vleuten_de_meern_df.iloc[[0]]
#       6 vleuten_de_meern_df['Area']='Vleuten - De Meern'
#
# ~\anaconda3\envs\eolearn\lib\site-packages\pylandstats\landscape.py in compute_class_metrics_df(self, metrics, classes, metrics_kws)
#    2567                     raise ValueError(
#    2568                         "{metric} cannot be computed at the class level".
# -> 2569                         format(metric=metric))
#    2570
#    2571         if classes is None:
#
# ...

# %%
west = pls.Landscape(landscape="C:/Users/piete/Documents/HU/DDD/D/Prototype/Data/Remote Sensing/S2A_MSIL2A_20200507T104031_N0214_R008_T31UFT_20200507T133648.SAFE/GRANULE/L2A_T31UFT_A025459_20200507T104558/IMG_DATA/Utrecht_Definitief/Classifications/west_classification.tif")

west_df = west.compute_class_metrics_df(
    metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn', 'euclidean_nearest_neighbor_mn'])
west_df = west_df.iloc[[1]]
west_df['Area']='West'
west_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-5fdf19414e57> in <module>
#       2
#       3 west_df = west.compute_class_metrics_df(
# ----> 4     metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn', 'euclidean_nearest_neighbor'])
#       5 west_df = west_df.iloc[[1]]
#       6 west_df['Area']='West'
#
# ~\anaconda3\envs\eolearn\lib\site-packages\pylandstats\landscape.py in compute_class_metrics_df(self, metrics, classes, metrics_kws)
#    2567                     raise ValueError(
#    2568                         "{metric} cannot be computed at the class level".
# -> 2569                         format(metric=metric))
#    2570
#    2571         if classes is None:
#
# ValueError: euclidean_nearest_neighbor cannot be computed at the class level

# %%
zuid = pls.Landscape(landscape="C:/Users/piete/Documents/HU/DDD/D/Prototype/Data/Remote Sensing/S2A_MSIL2A_20200507T104031_N0214_R008_T31UFT_20200507T133648.SAFE/GRANULE/L2A_T31UFT_A025459_20200507T104558/IMG_DATA/Utrecht_Definitief/Classifications/zuid_classification.tif")

zuid_df = zuid.compute_class_metrics_df(
    metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn', 'euclidean_nearest_neighbor_mn'])
zuid_df = zuid_df.iloc[[1]]
zuid_df['Area']='Zuid'
zuid_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-9cd7687ae83f> in <module>
#       2
#       3 zuid_df = zuid.compute_class_metrics_df(
# ----> 4     metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn', 'euclidean_nearest_neighbor'])
#       5 zuid_df = zuid_df.iloc[[1]]
#       6 zuid_df['Area']='Zuid'
#
# ~\anaconda3\envs\eolearn\lib\site-packages\pylandstats\landscape.py in compute_class_metrics_df(self, metrics, classes, metrics_kws)
#    2567                     raise ValueError(
#    2568                         "{metric} cannot be computed at the class level".
# -> 2569                         format(metric=metric))
#    2570
#    2571         if classes is None:
#
# ValueError: euclidean_nearest_neighbor cannot be computed at the class level

# %%
zuidwest = pls.Landscape(landscape="C:/Users/piete/Documents/HU/DDD/D/Prototype/Data/Remote Sensing/S2A_MSIL2A_20200507T104031_N0214_R008_T31UFT_20200507T133648.SAFE/GRANULE/L2A_T31UFT_A025459_20200507T104558/IMG_DATA/Utrecht_Definitief/Classifications/zuidwest_classification.tif")

zuidwest_df = zuidwest.compute_class_metrics_df(
    metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn', 'euclidean_nearest_neighbor_mn'])
zuidwest_df = zuidwest_df.iloc[[1]]
zuidwest_df['Area']='Zuidwest'
zuidwest_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-9c77e24314c2> in <module>
#       2
#       3 zuidwest_df = zuidwest.compute_class_metrics_df(
# ----> 4     metrics=['total_area', 'proportion_of_landscape','patch_density', 'largest_patch_index', 'area_mn', 'euclidean_nearest_neighbor'])
#       5 zuidwest_df = zuidwest_df.iloc[[1]]
#       6 zuidwest_df['Area']='Zuidwest'
#
# ~\anaconda3\envs\eolearn\lib\site-packages\pylandstats\landscape.py in compute_class_metrics_df(self, metrics, classes, metrics_kws)
#    2567                     raise ValueError(
#    2568                         "{metric} cannot be computed at the class level".
# -> 2569                         format(metric=metric))
#    2570
#    2571         if classes is None:
#
# ValueError: euclidean_nearest_neighbor cannot be computed at the class level

# %%
import pandas as pd
fragstats = pd.concat([zuidwest_df, zuid_df, binnenstad_df, west_df, vleuten_de_meern_df, leidsche_rijn_df, noordoost_df, noordwest_df, oost_df, overvecht_df, total_df])
fragstats
# Out:
#            total_area  proportion_of_landscape  patch_density  \
# class_val
# 1               71.29                12.840418      83.573487
# 1              164.80                34.834809      65.315268
# 1               19.99                 7.389199      70.602151
# 1              113.52                12.638470      55.220939
# 1             2107.65                57.202838      33.437191
# 1              269.79                23.970467      73.744347
# 1              139.94                27.591238      83.992192
# 1               75.21                16.596787      54.947480
# 1              504.86                45.733386      53.264729
# 1              355.77                41.945106      42.208022
# 1             3822.87                38.538161      50.626531
#
#            largest_patch_index   area_mn                Area
# class_val
# 1                     2.665706  0.153642            Zuidwest
# 1                    12.270393  0.533333                Zuid
# ...

# %%
fragstats.to_csv('fragstats_Utrecht.csv')
